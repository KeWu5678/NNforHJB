# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# %load_ext nb_black

from pathlib import Path
import sys

sys.path.insert(0, Path().absolute().parent.as_posix())
# Out:
# /Users/ruizhechao/Documents/NNforHJB
# /Users/ruizhechao/Documents/NNforHJB/.venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# Import and test the DateGenerator
from scr.data_generation_VDP import DateGenerator

# Instantiate the generator
VDP_openloop = DateGenerator(beta=0.1)

# Build grids and allocate arrays
VDP_openloop.apply_randoom_initial_sampling(N = 100)

# Run the data generation 
dataset, ini_fail = VDP_openloop.data_generation()

# # Save results under ../rawdata/raw_data/
# generator.data_save()
# Out:
# Randomly sampled 100 points in range x1: [-3, 3], x2: [-3, 3]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       8 VDP_openloop.apply_randoom_initial_sampling(N = 100)
#      10 # Run the data generation
# ---> 11 dataset, ini_fail = VDP_openloop.data_generation()
#      13 # # Save results under ../rawdata/raw_data/
#      14 # generator.data_save()
#
# File ~/Documents/NNforHJB/src/data_generation_VDP.py:103, in DateGenerator.data_generation(self, tol, max_it)
#     101 # time diecretization
#     102 grid = np.arange(0.0, self.T_final + self.dt, self.dt)
# --> 103 guess = np.ones((4, self.grid.size))
#     105 N = self.x0_values.shape[0]
#     106 dtype = [('x', '2float64'), ('dv', '2float64'), ('v', 'float64')]
#
# AttributeError: 'DateGenerator' object has no attribute 'grid'
