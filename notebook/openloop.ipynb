# %% [markdown]
# ## This notebook generate the data set of the Van der Pol equation

# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# %load_ext nb_black

from pathlib import Path
import sys

sys.path.insert(0, Path().absolute().parent.as_posix())
# Out:
# /Users/ruizhechao/Documents/NNforHJB

# %%
# # Import and test the DateGenerator
# from src.data_generation_VDP import DateGenerator

# # Instantiate the generator
# VDP_openloop = DateGenerator(beta=0.1)

# # Build grids and allocate arrays
# VDP_openloop.apply_randoom_initial_sampling(N = 100)

# # Run the data generation 
# dataset, ini_fail = VDP_openloop.data_generation()

# # # Save results under ../rawdata/raw_data/
# # generator.data_save()

import numpy as np
path = 'rawdata/raw_data/data/VDP_beta_0.1_grid_30x30.npy'
data = np.load(path)

# %%
from src.metric import plot_vdp_value_with_gradient_arrows2d, plot_vdp_value_scatter3d

plot_vdp_value_scatter3d(data)
plot_vdp_value_with_gradient_arrows2d(data)
# Out:
# (<Figure size 1200x1000 with 3 Axes>,
#  <Axes: title={'center': 'VDP dataset: V(x₀) with ∇V arrows'}, xlabel='x₀[0]', ylabel='x₀[1]'>)
