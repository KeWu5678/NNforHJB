# %%
import sys
import os

# Add the src directory to Python path so model.py can find ssn and net modules
sys.path.append(os.path.abspath('../src'))

from src.model import model
from src.model_outerweights import model_outerweights
from src.greedy_insertion import _sample_uniform_sphere_points
from src.training_logger import retrain

import numpy as np
from loguru import logger
import torch

# %%
# load the data
path = '../data_result/raw_data/VDP_beta_0.1_grid_combined.npy'# Initialize the weights
data = np.load(path)
logger.info(f"Loaded data with shape: {data.shape}, dtype: {data.dtype}")
# Out:
# 2025-09-08 10:26:37.415 | INFO     | __main__:<module>:4 - Loaded data with shape: (1800,), dtype: [('x', '<f8', (2,)), ('dv', '<f8', (2,)), ('v', '<f8')]

# %%
# Initialize the parameter
power = 2.1
M = 50 # number greedy insertion selected
num_iterations = 10
loss_weights = (1.0, 0.0)
pruning_threshold = 1e-15

gamma = 5.0
alpha = 1e-5
lr_adam = 1e-5
regularization = (gamma, alpha) 
th = 0.0

# %%
# Initialize the model 
model_1 = model(torch.relu, power, regularization, optimizer='Adam', loss_weights = loss_weights)
# Out:
# 2025-09-08 10:26:37 | INFO     | src.model:_configure_logger:87 - VDPModel initialized

# %%
# prepare the data
data_train, data_valid = model_1._prepare_data(0.8, data)
# Out:
# 2025-09-08 10:26:37 | INFO     | src.model:_prepare_data:136 - Training set: 1440 samples, Validation set: 360 samples
# 2025-09-08 10:26:37 | INFO     | src.model:_prepare_data:139 - Data ranges - x: [-3.00, 3.00], v: [0.00, 10.96], dv: [-13.19, 13.19]

# %%
# Set up the initializing weights and bias
init_weights, init_bias = _sample_uniform_sphere_points(M)

# %%
model_2 = model_outerweights(torch.relu, power, regularization, optimizer='SSN_TR', loss_weights = loss_weights, th = th)
# Out:
# 2025-09-08 10:26:37 | INFO     | src.model_outerweights:_configure_logger:88 - VDPModel (outer weights) initialized

# %%
model_result, weight_raw, bias_raw, outerweight_raw = model_1.train(
    data_train=data_train,
    data_valid=data_valid,
    inner_weights=init_weights, 
    inner_bias=init_bias,
    iterations=1000,
    display_every=200,
)
logger.info("Initialization done"); logger.info(f"Initial weights shape: {weight_raw.shape}, bias shape: {bias_raw.shape}")
# Out:
# 2025-09-08 10:26:37 | INFO     | src.model:train:255 - Starting network training session
# 2025-09-08 10:26:37 | INFO     | src.model:_create_network:173 - Creating network with 50 neurons
# 2025-09-08 10:26:38 | INFO     | src.model:_setup_optimizer:199 - Using Adam optimizer with lr=0.01
# 2025-09-08 10:26:38 | INFO     | src.model:train:273 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 10:26:38 | INFO     | src.model:train:274 - Training hyperparameters: iterations=1000, batch_size=1620, display_every=200
# 2025-09-08 10:26:38 | INFO     | src.model:train:275 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 10:26:38 | INFO     | src.model:train:320 - Epoch 0: Train Loss = 15.458950, Val Loss = 10.241357
# 2025-09-08 10:26:39 | INFO     | src.model:train:320 - Epoch 200: Train Loss = 0.133680, Val Loss = 0.120799
# 2025-09-08 10:26:40 | INFO     | src.model:train:320 - Epoch 400: Train Loss = 0.037234, Val Loss = 0.035111
# 2025-09-08 10:26:40 | INFO     | src.model:train:320 - Epoch 600: Train Loss = 0.009803, Val Loss = 0.008954
# 2025-09-08 10:26:41 | INFO     | src.model:train:320 - Epoch 800: Train Loss = 0.004775, Val Loss = 0.004367
# 2025-09-08 10:26:41 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 10:26:41 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 10:26:41 | INFO     | __main__:<module>:9 - Initialization done
# 2025-09-08 10:26:41 | INFO     | __main__:<module>:9 - Initial weights shape: (50, 2), bias shape: (50,)

# %%
# Training with improved logging
VDP_logger_L2_nc, weight_raw, bias_raw, outerweight_raw = retrain(
    data_train, data_valid, 
    model_1, model_2, model_result, weight_raw, bias_raw, outerweight_raw,
    num_iterations, M, alpha, pruning_threshold, power, gamma
)

logger.info("Training completed with improved logging")
# Out:
# 2025-09-08 10:26:41 | INFO     | src.training_logger:retrain:141 - Iteration 0 - weights shape: (50, 2)
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:train:251 - Starting network training session (outer weights only)
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:_setup_optimizer:188 - Using SSN_TR optimizer with alpha=1e-05, gamma=5.0, th=0.0
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:train:267 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:train:268 - Training hyperparameters: iterations=5000, batch_size=1620, display_every=1000
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:train:269 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 10:26:41 | INFO     | src.model_outerweights:train:314 - Epoch 0: Train Loss = 0.003199, Val Loss = 0.002891
# 2025-09-08 10:26:57 | INFO     | src.model_outerweights:train:314 - Epoch 1000: Train Loss = 0.003199, Val Loss = 0.002891
# 2025-09-08 10:27:11 | INFO     | src.model_outerweights:train:314 - Epoch 2000: Train Loss = 0.003199, Val Loss = 0.002891
# 2025-09-08 10:27:26 | INFO     | src.model_outerweights:train:314 - Epoch 3000: Train Loss = 0.003199, Val Loss = 0.002891
# 2025-09-08 10:27:41 | INFO     | src.model_outerweights:train:314 - Epoch 4000: Train Loss = 0.003199, Val Loss = 0.002891
# 2025-09-08 10:27:55 | INFO     | src.model_outerweights:train:329 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_outerweights_final.pt
# 2025-09-08 10:27:55 | INFO     | src.model_outerweights:train:361 - Training completed successfully (outer weights only)
# 2025-09-08 10:27:55 | INFO     | src.training_logger:retrain:159 - Small weights count: 1
# 2025-09-08 10:27:55 | INFO     | src.training_logger:prune_small_weights:81 - prune_small_weights - weights: (50, 2), biases: (50,), outer_weights: (1, 50)
# 2025-09-08 10:27:55 | INFO     | src.training_logger:prune_small_weights:90 - Pruning 1 neurons with small weights
# 2025-09-08 10:27:55 | INFO     | src.training_logger:prune_small_weights:102 - After pruning - weights: (49, 2), biases: (49,), outer_weights: (1, 49)
# 2025-09-08 10:27:58 | INFO     | src.model:train:255 - Starting network training session
# 2025-09-08 10:27:58 | INFO     | src.model:_create_network:173 - Creating network with 97 neurons
# 2025-09-08 10:27:58 | INFO     | src.model:_setup_optimizer:199 - Using Adam optimizer with lr=0.01
# 2025-09-08 10:27:58 | INFO     | src.model:train:273 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 10:27:58 | INFO     | src.model:train:274 - Training hyperparameters: iterations=20000, batch_size=1620, display_every=1000
# 2025-09-08 10:27:58 | INFO     | src.model:train:275 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 10:27:58 | INFO     | src.model:train:320 - Epoch 0: Train Loss = 15.458950, Val Loss = 6.890598
# 2025-09-08 10:28:02 | INFO     | src.model:train:320 - Epoch 1000: Train Loss = 0.001722, Val Loss = 0.001693
# 2025-09-08 10:28:07 | INFO     | src.model:train:320 - Epoch 2000: Train Loss = 0.000628, Val Loss = 0.000612
# 2025-09-08 10:28:12 | INFO     | src.model:train:320 - Epoch 3000: Train Loss = 0.000476, Val Loss = 0.000501
# 2025-09-08 10:28:17 | INFO     | src.model:train:320 - Epoch 4000: Train Loss = 0.000379, Val Loss = 0.000401
# 2025-09-08 10:28:21 | INFO     | src.model:train:320 - Epoch 5000: Train Loss = 0.000333, Val Loss = 0.000359
# 2025-09-08 10:28:26 | INFO     | src.model:train:320 - Epoch 6000: Train Loss = 0.000303, Val Loss = 0.000330
# 2025-09-08 10:28:31 | INFO     | src.model:train:320 - Epoch 7000: Train Loss = 0.000282, Val Loss = 0.000306
# 2025-09-08 10:28:36 | INFO     | src.model:train:320 - Epoch 8000: Train Loss = 0.000262, Val Loss = 0.000284
# 2025-09-08 10:28:41 | INFO     | src.model:train:320 - Epoch 9000: Train Loss = 0.000247, Val Loss = 0.000268
# 2025-09-08 10:28:46 | INFO     | src.model:train:320 - Epoch 10000: Train Loss = 0.030449, Val Loss = 0.019029
# 2025-09-08 10:28:50 | INFO     | src.model:train:320 - Epoch 11000: Train Loss = 0.000591, Val Loss = 0.000823
# 2025-09-08 10:28:55 | INFO     | src.model:train:320 - Epoch 12000: Train Loss = 0.000198, Val Loss = 0.000225
# 2025-09-08 10:29:00 | INFO     | src.model:train:320 - Epoch 13000: Train Loss = 0.000186, Val Loss = 0.000210
# 2025-09-08 10:29:05 | INFO     | src.model:train:320 - Epoch 14000: Train Loss = 0.000262, Val Loss = 0.000240
# 2025-09-08 10:29:09 | INFO     | src.model:train:320 - Epoch 15000: Train Loss = 0.000171, Val Loss = 0.000187
# 2025-09-08 10:29:15 | INFO     | src.model:train:320 - Epoch 16000: Train Loss = 0.000164, Val Loss = 0.000177
# 2025-09-08 10:29:20 | INFO     | src.model:train:320 - Epoch 17000: Train Loss = 0.000165, Val Loss = 0.000180
# 2025-09-08 10:29:24 | INFO     | src.model:train:320 - Epoch 18000: Train Loss = 0.000159, Val Loss = 0.000171
# 2025-09-08 10:29:29 | INFO     | src.model:train:320 - Epoch 19000: Train Loss = 0.000160, Val Loss = 0.000171
# 2025-09-08 10:29:34 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 10:29:34 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 10:29:34 | INFO     | src.training_logger:retrain:190 - New best model found at iteration 0 with validation loss: 0.002891
# 2025-09-08 10:29:34 | INFO     | src.training_logger:log_best_model:52 - Best model updated with test_loss=0.002891
# 2025-09-08 10:29:34 | INFO     | src.training_logger:log_iteration:45 - Iteration 0: 97 neurons, test_loss=0.002891
# 2025-09-08 10:29:34 | INFO     | src.training_logger:retrain:141 - Iteration 1 - weights shape: (97, 2)
# 2025-09-08 10:29:34 | INFO     | src.model_outerweights:train:251 - Starting network training session (outer weights only)
# 2025-09-08
| INFO     | src.model:train:320 - Epoch 17000: Train Loss = 0.000160, Val Loss = 0.000165
# 2025-09-08 11:45:41 | INFO     | src.model:train:320 - Epoch 18000: Train Loss = 0.000158, Val Loss = 0.000163
# 2025-09-08 11:45:51 | INFO     | src.model:train:320 - Epoch 19000: Train Loss = 0.000156, Val Loss = 0.000160
# 2025-09-08 11:46:01 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 11:46:01 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 11:46:01 | INFO     | src.training_logger:log_iteration:45 - Iteration 9: 234 neurons, test_loss=0.000114
# 2025-09-08 11:46:01 | INFO     | src.training_logger:save:63 - Saved training history to /Users/ruizhechao/Documents/NNforHJB/data_result/weights/training_history_20250908_114601.pkl
# 2025-09-08 11:46:01 | INFO     | src.training_logger:retrain:199 - Training completed. History saved to /Users/ruizhechao/Documents/NNforHJB/data_result/weights/training_history_20250908_114601.pkl
# 2025-09-08 11:46:01 | INFO     | src.training_logger:retrain:200 - Best validation loss: 0.000114
# 2025-09-08 11:46:01 | INFO     | __main__:<module>:8 - Training completed with improved logging

# %% [markdown]
# Reached error 1.71e-4 at 97 neurons

# %%
# =============================================================================
# PLOT: Weight space visualization in polar coordinates
# Shows the distribution of weights in 2D space for the BEST model (lowest validation loss)
# =============================================================================

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Extract weights from the current training run
weights_run = VDP_logger_L2_nc.history['weights']
biases_run = VDP_logger_L2_nc.history['biases']
neurons_run = VDP_logger_L2_nc.history['neuron_count']

print(f"Training run: {len(weights_run)} iterations, max neurons: {max(neurons_run)}")

# Use the BEST model (lowest validation loss) instead of the iteration with most neurons
print("Using BEST model (lowest validation loss)")
weights_optimal = VDP_logger_L2_nc.history['best_weights']
b_optimal = VDP_logger_L2_nc.history['best_biases'].reshape(1, -1)   # (1, n)
best_loss = VDP_logger_L2_nc.history['best_test_loss']
print(f"Best validation loss: {best_loss:.6f}")

a_optimal = weights_optimal.T                         # (2, n)
Z = a_optimal / (1 + b_optimal) 

# Create polar coordinate visualization
fig, ax = plt.subplots(1, 1, figsize=(10, 8), subplot_kw={'projection': 'polar'})

# Compute angles and radii in weight space (2D)
angles = np.arctan2(a_optimal[1], a_optimal[0])
r_sphere = np.sqrt(np.sum(a_optimal**2, axis=0) + (b_optimal.flatten())**2)

# Plot in polar coordinates
radius = np.ones_like(angles)
ax.scatter(angles, radius, c=b_optimal.flatten(), cmap='coolwarm', alpha=0.85, s=60)
ax.set_title(f'Weight Space - BEST Model\nNeurons: {weights_optimal.shape[0]}', fontsize=14)
ax.grid(True, alpha=0.5)

# Save the figure
plt.savefig('../data_result/plot/weights_polar_analysis_best.png', dpi=300, bbox_inches='tight')
print(f"Polar coordinate analysis saved to ../data_result/plot/weights_polar_analysis_best.png")

# Show plot
plt.show()
# Out:
# Training run: 10 iterations, max neurons: 263
# Using BEST model (lowest validation loss)
# Best validation loss: 0.000114
# Polar coordinate analysis saved to ../data_result/plot/weights_polar_analysis_best.png

# %% [markdown]
# ## Test with the L1 Penalty ##

# %%
# Initialize the parameter
power = 2.1
M = 50 # number greedy insertion selected
num_iterations = 10
loss_weights = (1.0, 0.0)
pruning_threshold = 1e-13

gamma = 1e-10
alpha = 1e-5
regularization = (gamma, alpha) 
th = 1.0

# %% [markdown]
# The comparable model is about: 207 neurons

# %%
# Initialize the model 
model_1 = model(torch.relu, power, regularization, optimizer='Adam', loss_weights = loss_weights)
model_2 = model_outerweights(torch.relu, power, regularization, optimizer='SSN_TR', loss_weights = loss_weights, th = th)

# Prepare data
data_train, data_valid = model_1._prepare_data(0.8, data)

# Set up the initializing weights and bias
init_weights = np.random.randn(M, 2) * 0.1
init_bias = np.random.randn(M)

model_result, weight_raw, bias_raw, outerweight_raw = model_1.train(
    data_train=data_train,
    data_valid=data_valid,
    inner_weights=init_weights, 
    inner_bias=init_bias,
    iterations=1000,
    display_every=200,
)
logger.info("Initialization done"); logger.info(f"Initial weights shape: {weight_raw.shape}, bias shape: {bias_raw.shape}")

# Training with improved logging
VDP_logger_L2_lasso, weight_raw_1, bias_raw_1, outerweight_raw_1 = retrain(
    data_train, data_valid, model_1, model_2, model_result, weight_raw, bias_raw, outerweight_raw,
    num_iterations, M, alpha, pruning_threshold, power, gamma
)

logger.info("Training completed with improved logging")
# Out:
# 2025-09-08 11:46:02 | INFO     | src.model:_configure_logger:87 - VDPModel initialized
# 2025-09-08 11:46:02 | INFO     | src.model_outerweights:_configure_logger:88 - VDPModel (outer weights) initialized
# 2025-09-08 11:46:02 | INFO     | src.model:_prepare_data:136 - Training set: 1440 samples, Validation set: 360 samples
# 2025-09-08 11:46:02 | INFO     | src.model:_prepare_data:139 - Data ranges - x: [-3.00, 3.00], v: [0.00, 10.96], dv: [-13.19, 13.19]
# 2025-09-08 11:46:02 | INFO     | src.model:train:255 - Starting network training session
# 2025-09-08 11:46:02 | INFO     | src.model:_create_network:173 - Creating network with 50 neurons
# 2025-09-08 11:46:02 | INFO     | src.model:_setup_optimizer:199 - Using Adam optimizer with lr=0.01
# 2025-09-08 11:46:02 | INFO     | src.model:train:273 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 11:46:02 | INFO     | src.model:train:274 - Training hyperparameters: iterations=1000, batch_size=1620, display_every=200
# 2025-09-08 11:46:02 | INFO     | src.model:train:275 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 11:46:02 | INFO     | src.model:train:320 - Epoch 0: Train Loss = 15.458950, Val Loss = 13.460874
# 2025-09-08 11:46:03 | INFO     | src.model:train:320 - Epoch 200: Train Loss = 0.142144, Val Loss = 0.130270
# 2025-09-08 11:46:04 | INFO     | src.model:train:320 - Epoch 400: Train Loss = 0.077916, Val Loss = 0.066817
# 2025-09-08 11:46:04 | INFO     | src.model:train:320 - Epoch 600: Train Loss = 0.052680, Val Loss = 0.041222
# 2025-09-08 11:46:05 | INFO     | src.model:train:320 - Epoch 800: Train Loss = 0.026017, Val Loss = 0.018284
# 2025-09-08 11:46:06 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 11:46:06 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 11:46:06 | INFO     | __main__:<module>:20 - Initialization done
# 2025-09-08 11:46:06 | INFO     | __main__:<module>:20 - Initial weights shape: (50, 2), bias shape: (50,)
# 2025-09-08 11:46:06 | INFO     | src.training_logger:retrain:141 - Iteration 0 - weights shape: (50, 2)
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:train:251 - Starting network training session (outer weights only)
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:_setup_optimizer:188 - Using SSN_TR optimizer with alpha=1e-05, gamma=1e-10, th=1.0
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:train:267 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:train:268 - Training hyperparameters: iterations=5000, batch_size=1620, display_every=1000
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:train:269 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 11:46:06 | INFO     | src.model_outerweights:train:314 - Epoch 0: Train Loss = 0.012316, Val Loss = 0.008422
# 2025-09-08 11:46:16 | INFO     | src.model_outerweights:train:314 - Epoch 1000: Train Loss = 0.012316, Val Loss = 0.008422
# 2025-09-08 11:46:29 | INFO     | src.model_outerweights:train:314 - Epoch 2000: Train Loss = 0.012316, Val Loss = 0.008422
# 2025-09-08 11:46:41 | INFO     | src.model_outerweights:train:314 - Epoch 3000: Train Loss = 0.012316, Val Loss = 0.008422
# 2025-09-08 11:46:53 | INFO     | src.model_outerweights:train:314 - Epoch 4000: Train Loss = 0
| INFO     | src.model:train:320 - Epoch 17000: Train Loss = 0.010287, Val Loss = 0.003454
# 2025-09-08 12:46:40 | INFO     | src.model:train:320 - Epoch 18000: Train Loss = 0.000168, Val Loss = 0.000169
# 2025-09-08 12:46:51 | INFO     | src.model:train:320 - Epoch 19000: Train Loss = 0.000150, Val Loss = 0.000154
# 2025-09-08 12:47:01 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 12:47:01 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 12:47:01 | INFO     | src.training_logger:retrain:190 - New best model found at iteration 8 with validation loss: 0.000139
# 2025-09-08 12:47:01 | INFO     | src.training_logger:log_best_model:52 - Best model updated with test_loss=0.000139
# 2025-09-08 12:47:01 | INFO     | src.training_logger:log_iteration:45 - Iteration 8: 244 neurons, test_loss=0.000139
# 2025-09-08 12:47:01 | INFO     | src.training_logger:retrain:141 - Iteration 9 - weights shape: (244, 2)
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:train:251 - Starting network training session (outer weights only)
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:_setup_optimizer:188 - Using SSN_TR optimizer with alpha=1e-05, gamma=1e-10, th=1.0
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:train:267 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:train:268 - Training hyperparameters: iterations=5000, batch_size=1620, display_every=1000
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:train:269 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 12:47:01 | INFO     | src.model_outerweights:train:314 - Epoch 0: Train Loss = 0.000154, Val Loss = 0.000159
# 2025-09-08 12:47:47 | INFO     | src.model_outerweights:train:314 - Epoch 1000: Train Loss = 0.000154, Val Loss = 0.000159
# 2025-09-08 12:48:50 | INFO     | src.model_outerweights:train:314 - Epoch 2000: Train Loss = 0.000154, Val Loss = 0.000159
# 2025-09-08 12:49:55 | INFO     | src.model_outerweights:train:314 - Epoch 3000: Train Loss = 0.000154, Val Loss = 0.000159
# 2025-09-08 12:51:00 | INFO     | src.model_outerweights:train:314 - Epoch 4000: Train Loss = 0.000154, Val Loss = 0.000159
# 2025-09-08 12:52:04 | INFO     | src.model_outerweights:train:329 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_outerweights_final.pt
# 2025-09-08 12:52:04 | INFO     | src.model_outerweights:train:361 - Training completed successfully (outer weights only)
# 2025-09-08 12:52:04 | INFO     | src.training_logger:retrain:159 - Small weights count: 80
# 2025-09-08 12:52:04 | INFO     | src.training_logger:prune_small_weights:81 - prune_small_weights - weights: (244, 2), biases: (244,), outer_weights: (1, 244)
# 2025-09-08 12:52:04 | INFO     | src.training_logger:prune_small_weights:90 - Pruning 80 neurons with small weights
# 2025-09-08 12:52:04 | INFO     | src.training_logger:prune_small_weights:102 - After pruning - weights: (164, 2), biases: (164,), outer_weights: (1, 164)
# 2025-09-08 12:52:16 | INFO     | src.model:train:255 - Starting network training session
# 2025-09-08 12:52:16 | INFO     | src.model:_create_network:173 - Creating network with 214 neurons
# 2025-09-08 12:52:16 | INFO     | src.model:_setup_optimizer:199 - Using Adam optimizer with lr=0.01
# 2025-09-08 12:52:16 | INFO     | src.model:train:273 - Training model, saving to /Users/ruizhechao/Documents/NNforHJB/train_history
# 2025-09-08 12:52:16 | INFO     | src.model:train:274 - Training hyperparameters: iterations=20000, batch_size=1620, display_every=1000
# 2025-09-08 12:52:16 | INFO     | src.model:train:275 - Loss weights: value=1.0, gradient=0.0
# 2025-09-08 12:52:16 | INFO     | src.model:train:320 - Epoch 0: Train Loss = 15.458950, Val Loss = 6.492773
# 2025-09-08 12:52:25 | INFO     | src.model:train:320 - Epoch 1000: Train Loss = 0.000850, Val Loss = 0.000819
# 2025-09-08 12:52:34 | INFO     | src.model:train:320 - Epoch 2000: Train Loss = 0.000374, Val Loss = 0.000388
# 2025-09-08 12:52:43 | INFO     | src.model:train:320 - Epoch 3000: Train Loss = 0.023854, Val Loss = 0.014000
# 2025-09-08 12:52:51 | INFO     | src.model:train:320 - Epoch 4000: Train Loss = 0.000231, Val Loss = 0.000247
# 2025-09-08 12:53:00 | INFO     | src.model:train:320 - Epoch 5000: Train Loss = 0.000216, Val Loss = 0.000232
# 2025-09-08 12:53:09 | INFO     | src.model:train:320 - Epoch 6000: Train Loss = 0.000205, Val Loss = 0.000219
# 2025-09-08 12:53:17 | INFO     | src.model:train:320 - Epoch 7000: Train Loss = 0.000194, Val Loss = 0.000207
# 2025-09-08 12:53:26 | INFO     | src.model:train:320 - Epoch 8000: Train Loss = 0.000185, Val Loss = 0.000197
# 2025-09-08 12:53:35 | INFO     | src.model:train:320 - Epoch 9000: Train Loss = 0.000180, Val Loss = 0.000190
# 2025-09-08 12:53:44 | INFO     | src.model:train:320 - Epoch 10000: Train Loss = 0.000177, Val Loss = 0.000190
# 2025-09-08 12:53:53 | INFO     | src.model:train:320 - Epoch 11000: Train Loss = 0.002453, Val Loss = 0.001644
# 2025-09-08 12:54:02 | INFO     | src.model:train:320 - Epoch 12000: Train Loss = 0.000442, Val Loss = 0.000321
# 2025-09-08 12:54:10 | INFO     | src.model:train:320 - Epoch 13000: Train Loss = 0.001464, Val Loss = 0.000236
# 2025-09-08 12:54:20 | INFO     | src.model:train:320 - Epoch 14000: Train Loss = 0.002693, Val Loss = 0.002369
# 2025-09-08 12:54:29 | INFO     | src.model:train:320 - Epoch 15000: Train Loss = 0.000738, Val Loss = 0.000567
# 2025-09-08 12:54:39 | INFO     | src.model:train:320 - Epoch 16000: Train Loss = 0.000211, Val Loss = 0.000261
# 2025-09-08 12:54:50 | INFO     | src.model:train:320 - Epoch 17000: Train Loss = 0.000196, Val Loss = 0.000234
# 2025-09-08 12:54:59 | INFO     | src.model:train:320 - Epoch 18000: Train Loss = 0.000624, Val Loss = 0.000591
# 2025-09-08 12:55:09 | INFO     | src.model:train:320 - Epoch 19000: Train Loss = 0.000198, Val Loss = 0.000230
# 2025-09-08 12:55:18 | INFO     | src.model:train:335 - Final model saved to /Users/ruizhechao/Documents/NNforHJB/train_history/model_final.pt
# 2025-09-08 12:55:18 | INFO     | src.model:train:367 - Training completed successfully
# 2025-09-08 12:55:18 | INFO     | src.training_logger:log_iteration:45 - Iteration 9: 214 neurons, test_loss=0.000139
# 2025-09-08 12:55:18 | INFO     | src.training_logger:save:63 - Saved training history to /Users/ruizhechao/Documents/NNforHJB/data_result/weights/training_history_20250908_125518.pkl
# 2025-09-08 12:55:18 | INFO     | src.training_logger:retrain:199 - Training completed. History saved to /Users/ruizhechao/Documents/NNforHJB/data_result/weights/training_history_20250908_125518.pkl
# 2025-09-08 12:55:18 | INFO     | src.training_logger:retrain:200 - Best validation loss: 0.000139
# 2025-09-08 12:55:18 | INFO     | __main__:<module>:28 - Training completed with improved logging

# %% [markdown]
# Reached 2.3e-4 at 131 neurones
# Reached 1.96e-4 at 213 neurones

# %%
# =============================================================================
# PLOT: Weight space visualization in polar coordinates
# Shows the distribution of weights in 2D space for the BEST model (lowest validation loss)
# =============================================================================

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Extract weights from the current training run
weights_run = VDP_logger_L2_lasso.history['weights']
biases_run = VDP_logger_L2_lasso.history['biases']
neurons_run = VDP_logger_L2_lasso.history['neuron_count']

print(f"Training run: {len(weights_run)} iterations, max neurons: {max(neurons_run)}")

# Use the BEST model (lowest validation loss) instead of the iteration with most neurons
if 'best_weights' in VDP_logger_L2_lasso.history:
    print("Using BEST model (lowest validation loss)")
weights_optimal = VDP_logger_L2_lasso.history['best_weights']
b_optimal = VDP_logger_L2_lasso.history['best_biases'].reshape(1, -1)   # (1, n)
best_loss = VDP_logger_L2_lasso.history['best_test_loss']
print(f"Best validation loss: {best_loss:.6f}")

a_optimal = weights_optimal.T                         # (2, n)
Z = a_optimal / (1 + b_optimal) 

# Create polar coordinate visualization
fig, ax = plt.subplots(1, 1, figsize=(10, 8), subplot_kw={'projection': 'polar'})

# Compute angles and radii in weight space (2D)
angles = np.arctan2(a_optimal[1], a_optimal[0])
r_sphere = np.sqrt(np.sum(a_optimal**2, axis=0) + (b_optimal.flatten())**2)

# Plot in polar coordinates
radius = np.ones_like(angles)
ax.scatter(angles, radius, c=b_optimal.flatten(), cmap='coolwarm', alpha=0.85, s=60)
ax.set_title(f'Weight Space - BEST Model (L1 Penalty)\nNeurons: {weights_optimal.shape[0]}', fontsize=14)
ax.grid(True, alpha=0.5)

# Save the figure
plt.savefig('../data_result/plot/weights_polar_analysis_best_l1.png', dpi=300, bbox_inches='tight')
print(f"Polar coordinate analysis saved to ../data_result/plot/weights_polar_analysis_best_l1.png")

# Show plot
plt.show()


# Optional: Show weight evolution across iterations
if len(weights_run) > 1:
    print(f"\n=== Weight Evolution ===")
    print("Neuron counts across iterations:")
    for i, count in enumerate(neurons_run):
        print(f"Iteration {i}: {count} neurons")
# Out:
# Training run: 10 iterations, max neurons: 244
# Using BEST model (lowest validation loss)
# Best validation loss: 0.000139
# Polar coordinate analysis saved to ../data_result/plot/weights_polar_analysis_best_l1.png
# === Weight Evolution ===
# Neuron counts across iterations:
# Iteration 0: 81 neurons
# Iteration 1: 131 neurons
# Iteration 2: 181 neurons
# Iteration 3: 213 neurons
# Iteration 4: 237 neurons
# Iteration 5: 243 neurons
# Iteration 6: 237 neurons
# Iteration 7: 236 neurons
# Iteration 8: 244 neurons
# Iteration 9: 214 neurons
